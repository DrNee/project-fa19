# %%
import random
import string
import numpy as np

# %%
def randomMetricGraph(numOfVertices, lowerLimit, upperLimit, edgeProb):
	X = np.random.uniform(lowerLimit, upperLimit, numOfVertices)
	Y = np.random.uniform(lowerLimit, upperLimit, numOfVertices)
	G = np.empty((numOfVertices, numOfVertices))
	for i in range(numOfVertices):
		for j in range(i+1):
			a = np.array((X[i], Y[i]))
			b = np.array((X[j], Y[j]))
			G[i, j] = np.linalg.norm(a-b) if np.random.uniform() > edgeProb else 0
            G[j, i] = np.linalg.norm(a-b) if np.random.uniform() > edgeProb else 0
	return '\n'.join( ( ' '.join(str(d) if d>0 else 'x' for d in row) for row in G ) )

# %%
def rand_string(strlen=10):
    letters = string.ascii_lowercase
    return ''.join(random.choice(letters) for i in range(strlen))

# %%
A_50 = gen_matrix(50)
num_homes = random.randint(15, 25)
locs = []
homes = set([])

print(50)
print(num_homes)

for i in range(50):
    locs.append(rand_string())
    if i == 49:
        print(locs[i])
    else:
        print(locs[i], end=' ')
        
while len(homes) < num_homes:
    homes.add(random.choice(locs))
    
homes = list(homes)
    
for i in range(num_homes):
    if i == (num_homes - 1):
        print(homes[i])
    else:
        print(homes[i], end=' ')   

for a in A_50:
    for i in range(50):
        if i == 49:
            print(a[i])
        else:
            print(a[i], end=' ')
# Out:
# 50
# 21
# gbanunuajm csoefmaeni isvmguzrgx cilugivmuz uucmjussyb fbsbqksopo kbqzmkuzxv knalfwobfz lempeiuxdg mbrbyrfair jaicgbvkea ksfkzzxvst pjomvmypzt ptnhsytzzg fclyqqxwus cfdimwczko qnzdnkxwvo mvgcwwcfso cgubwrywts ugegquvouz lqnzfurhgy izqonnslnz drrymruhxx bgwaybcice codpxmrwsk lfzuifzzui mcdgymxxkz rksvgtmmak xzvkhynwcl tmahmicycm pdjcjykkpg lclbbrcifb hqnwortypo qqoltlcqyo jvatlwrekk agfvxvqxpb pllduvjrfd wivajwujbh sugeozgkkt buqephtjyx smtulaulca warktviszb yauerrfltq nzfkkfoley qztemuqazc hdrnzokbxf kocdbtvxlv iwncgksaks pwxpcianks iskhcjpuxs
# izqonnslnz pwxpcianks yauerrfltq mcdgymxxkz ptnhsytzzg jaicgbvkea agfvxvqxpb lclbbrcifb iskhcjpuxs sugeozgkkt xzvkhynwcl qztemuqazc buqephtjyx mbrbyrfair kocdbtvxlv lfzuifzzui cfdimwczko bgwaybcice codpxmrwsk ksfkzzxvst uucmjussyb
# ...

# %%
A_100 = gen_matrix(100)
num_homes = random.randint(40, 50)
locs = []
homes = set([])

print(100)
print(num_homes)

for i in range(100):
    locs.append(rand_string())
    if i == 99:
        print(locs[i])
    else:
        print(locs[i], end=' ')
        
while len(homes) < num_homes:
    homes.add(random.choice(locs))
    
homes = list(homes)
    
for i in range(num_homes):
    if i == (num_homes - 1):
        print(homes[i])
    else:
        print(homes[i], end=' ')   

for a in A_100:
    for i in range(100):
        if i == 99:
            print(a[i])
        else:
            print(a[i], end=' ')
# Out:
# 100
# 40
# ...

# %%
A_200 = gen_matrix(200)
num_homes = random.randint(80, 100)
locs = []
homes = set([])

print(200)
print(num_homes)

for i in range(200):
    locs.append(rand_string())
    if i == 199:
        print(locs[i])
    else:
        print(locs[i], end=' ')
        
while len(homes) < num_homes:
    homes.add(random.choice(locs))
    
homes = list(homes)
    
for i in range(num_homes):
    if i == (num_homes - 1):
        print(homes[i])
    else:
        print(homes[i], end=' ')   

for a in A_200:
    for i in range(200):
        if i == 199:
            print(a[i])
        else:
            print(a[i], end=' ')
# Out:
# 200
# 98
# ...
